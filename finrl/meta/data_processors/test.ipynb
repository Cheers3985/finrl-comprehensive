# %%
import yfinance as yf
import pytz
from tzlocal import get_localzone
# tz = pytz.timezone.utc
local = pytz.timezone('UTC')
print(local)
tic = ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC']
start_date = '2008-01-01'
end_date = '2021-10-31'
time_interval='1D'
temp_df = yf.download(tic, start=start_date, end=end_date, interval=time_interval,proxy='127.0.0.1:10809')  
print(temp_df)
# Out:
# UTC
# Exception in thread Thread-40:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
# Exception in thread Thread-41:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
# Exception in thread Thread-42:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
# Exception in thread Thread-43:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 171, in history
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
# Exception in thread Thread-44:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
# Exception in thread Thread-45:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 171, in history
# Exception in thread Thread-46:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     dt = _tz.timezone(exchange_tz).localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 171, in history
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'nan'
# Exception in thread Thread-47:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
#     dt = _tz.timezone(exchange_tz).localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 171, in history
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'nan'
#         end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
# self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
#     dt = _tz.timezone(exchange_tz).localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
# Exception in thread Thread-49:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     dt = _tz.timezone(exchange_tz).localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
# Exception in thread Thread-50:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 171, in history
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 171, in history
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'nan'
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
# Exception in thread Thread-48:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'nan'
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
# Exception in thread Thread-51:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
#     dt = _tz.timezone(exchange_tz).localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
#     dt = _tz.timezone(exchange_tz).localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'nan'
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 171, in history
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 171, in history
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'nan'
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 171, in history
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 171, in history
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     dt = _tz.timezone(exchange_tz).localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 171, in history
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
#     dt = _tz.timezone(exchange_tz).localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'nan'
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'nan'
#     dt = _tz.timezone(exchange_tz).localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
#     dt = _tz.timezone(exchange_tz).localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'nan'
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'nan'
#     dt = _tz.timezone(exchange_tz).localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 171, in history
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'nan'
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     dt = _tz.timezone(exchange_tz).localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'nan'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [4], line 11
#       9 end_date = '2021-10-31'
#      10 time_interval='1D'
# ---> 11 temp_df = yf.download(tic, start=start_date, end=end_date, interval=time_interval,proxy='127.0.0.1:10809')
#      12 print(temp_df)
#
# File ~/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py:118, in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, keepna, progress, period, show_errors, interval, prepost, proxy, rounding, timeout, **kwargs)
#     111         _download_one_threaded(ticker, period=period, interval=interval,
#     112                                start=start, end=end, prepost=prepost,
#     113                                actions=actions, auto_adjust=auto_adjust,
#     114                                back_adjust=back_adjust, keepna=keepna,
#     115                                progress=(progress and i > 0), proxy=proxy,
#     116                                rounding=rounding, timeout=timeout)
#     117     while len(shared._DFS) < len(tickers):
# --> 118         _time.sleep(0.01)
#     120 # download synchronously
#     121 else:
#     122     for i, ticker in enumerate(tickers):
#
# KeyboardInterrupt:

# %%
import yfinance as yf
import pytz
# from tzlocal import get_localzone
# local = pytz.timezone('utc')
from tzlocal import get_localzone
local = pytz.timezone(str(get_localzone()))
print(local)
from datetime import datetime as datetime
tic = ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC']
start_date  = datetime (2008,1,1)
end_date   = datetime (2008,10,30)
# start_date = '2008-01-01'
# end_date = '2008-10-31'
time_interval='1D'
temp_df = yf.download(tic, start=start_date, end=end_date, interval=time_interval,proxy='127.0.0.1:10809')  
print(temp_df)
# Out:
# Asia/Shanghai
# Exception in thread Thread-28:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-29:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
# Exception in thread Thread-30:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
# Exception in thread Thread-31:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
# Exception in thread Thread-32:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
# Exception in thread Thread-33:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
# Exception in thread Thread-34:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
# Exception in thread Thread-35:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 170, in history
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
# Exception in thread Thread-36:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
# Exception in thread Thread-37:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 170, in history
#     dt = _tz.timezone('Asia/Shanghai').localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
# Exception in thread Thread-38:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 170, in history
# Exception in thread Thread-39:
# Traceback (most recent call last):
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 170, in history
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
#     dt = _tz.timezone('Asia/Shanghai').localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'Asia/Shangri-La'
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'Asia/Shangri-La'
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     self.run()
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/threading.py", line 870, in run
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 170, in history
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#         data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
# dt = _tz.timezone('Asia/Shanghai').localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
#     dt = _tz.timezone('Asia/Shanghai').localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     self._target(*self._args, **self._kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/multitasking/__init__.py", line 104, in _run_via_pool
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 170, in history
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 170, in history
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 170, in history
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'Asia/Shangri-La'
#     return callee(*args, **kwargs)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 199, in _download_one_threaded
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'Asia/Shangri-La'
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 170, in history
#     dt = _tz.timezone('Asia/Shanghai').localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'Asia/Shangri-La'
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 170, in history
#     dt = _tz.timezone('Asia/Shanghai').localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/multi.py", line 213, in _download_one
#     dt = _tz.timezone('Asia/Shanghai').localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 170, in history
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     dt = _tz.timezone('Asia/Shanghai').localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
#     return Ticker(ticker).history(period=period, interval=interval,
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/base.py", line 170, in history
#     dt = _tz.timezone('Asia/Shanghai').localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
#     end = utils._parse_user_dt(end, tz)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/yfinance/utils.py", line 157, in _parse_user_dt
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'Asia/Shangri-La'
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'Asia/Shangri-La'
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'Asia/Shangri-La'
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'Asia/Shangri-La'
#         dt = _tz.timezone('Asia/Shanghai').localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
#     dt = _tz.timezone('Asia/Shanghai').localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
# dt = _tz.timezone('Asia/Shanghai').localize(dt)
#   File "/home/cheers/anaconda3/envs/finrl/lib/python3.8/site-packages/pytz/__init__.py", line 189, in timezone
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'Asia/Shangri-La'
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'Asia/Shangri-La'
#     raise UnknownTimeZoneError(zone)
# pytz.exceptions.UnknownTimeZoneError: 'Asia/Shangri-La'
